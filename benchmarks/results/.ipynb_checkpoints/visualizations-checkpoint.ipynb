# %%
import yaml
from inspect import getsourcefile
import os.path
import os
os.system('module load gurobipy3')

import sys
import matplotlib

import matplotlib.pyplot as plt
import argparse
# import gurobipy
current_path = os.path.abspath(getsourcefile(lambda:0))
current_dir = os.path.dirname(current_path)
parent_dir = os.path.dirname(current_dir)
parent_parent_dir = os.path.dirname(parent_dir)
sys.path.insert(0, parent_parent_dir+"/heuristics")

print(parent_parent_dir+"/heuristics")

# parent_dir = current_dir[:current_dir.rfind(os.path.sep)]
sys.path.insert(0, parent_parent_dir)


from group import SEIR_group, DynamicalModel
import math
import pprint
import pandas as pd
import pickle
import numpy as np
from copy import deepcopy
# Out:
# /usr/local/ifs/projects/daniancu-covid-targets/covid-optimization/heuristics

# %%
etas = [0.1]
deltas = [0.5]
icus = [2000]
lockdown_freq=14
testing_freq=7
nmtests = [0]
natests = [0]

heurs = ["linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True","activity_gradient", "linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True", "linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient", "time_gradient", "activity_gradient","age_group_gradient", "dynamic_gradient"]
# "linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True"
# ,"dynamic_gradient"]
#  ["linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient"]
#  ["dynamic_gradient"]
# ["linearization_heuristic_optBouncing=False_initial_uhat=full_open"]
# ,"dynamic_gradient","linearization_heuristic_optBouncing=False_initial_uhat=full_lockdown","real","constant_gradient"]
# ["dynamic_gradient"]
# , "linearization_heuristic_optBouncing=False_initial_uhat=full_lockdown"]

# xi-0.0_icus-2000.0_testing-linearization_heuristic_natests-0.0_nmtests-0.0_T-90_startday-60_groups-all_dschool-0.5_eta-0_lockdownFreq-14_testingFreq-7

fig, ax = plt.subplots(2 + 2*len(heurs))

for h in heurs:
    for e in etas:
        for d in deltas:
            for i in icus:
                for nm in nmtests:
                    for na in natests:
                        all_deaths = []
                        all_econ_values = []
                        all_xis = []
                        all_rewards = []
                        symbols = ["*",".","d","o","s","^"]
                        
                        for file_name in os.listdir(h):
                            instance = file_name.split("_")

                            for p in instance:
                                if "xi" in p:
                                    xi = float(p.split("-")[1])
                    #                 print(xi)
                                if "icus" in p:
                                    icu = float(p.split("-")[1])
                    #                 print(icu)
                                if "natests" in p:
                                    natest = float(p.split("-")[1])
                    #                 print(natest)
                                if "nmtests" in p:
                                    nmtest = float(p.split("-")[1])
                    #                 print(nmtest)
                                if "dschool" in p:
                                    delta = float(p.split("-")[1])
                    #                 print(delta)
                                if "eta" in p:
                                    eta = float(p.split("-")[1])
                    #                 print(eta)
                            if eta == e and icu == i and nmtest == nm and natest == na and delta == d:
                                print(h)
                                print(instance)
                                
                                with open("%s/%s"%(h,file_name)) as file:
                                    result = yaml.load(file, Loader=yaml.UnsafeLoader)


                                # Read group parameters
                                with open("../../parameters/fitted.yaml") as file:
                                    universe_params_all = yaml.load(file, Loader=yaml.FullLoader)

                                # Read econ parameters
                                with open("../../parameters/econ.yaml") as file:
                                    econ_params_all = yaml.load(file, Loader=yaml.FullLoader)

                                # Read group parameters
                                with open("../../parameters/one_group_fitted.yaml") as file:
                                    universe_params_one = yaml.load(file, Loader=yaml.FullLoader)

                                # Read econ parameters
                                with open("../../parameters/one_group_econ.yaml") as file:
                                    econ_params_one = yaml.load(file, Loader=yaml.FullLoader)


                                start_day = result["experiment_params"]["start_day"]

                                if result["groups"] == "one":
                                    universe_params = universe_params_one
                                    econ_params = econ_params_one

                                    with open("../../initialization/%ddays_one_group.yaml"%start_day) as file:
                                        initialization = yaml.load(file, Loader=yaml.FullLoader)

                                elif result["groups"] == "all":
                                    universe_params = universe_params_all
                                    econ_params = econ_params_all

                                    with open("../../initialization/oct21.yaml") as file:
                                        initialization = yaml.load(file, Loader=yaml.FullLoader)
                                else:
                                    assert(False)

                                experiment_params = result["experiment_params"]

                                dynModel = DynamicalModel(universe_params, econ_params, experiment_params, initialization, 1, experiment_params["T"], universe_params["mixing"], start_day, result["experiment_params"]['eta'], extra_data = True)

                                for t in range(experiment_params["T"]):
                                    dynModel.take_time_step(result["m_tests"][t], result["a_tests"][t], result["policy"][t])

                                dynModel.take_end_steps()

                                deaths = dynModel.get_total_deaths()
                                econ_value = dynModel.get_total_reward() + dynModel.get_total_deaths() * xi 
                                reward = dynModel.get_total_reward()
                                
                                all_deaths.append(deaths)
                                all_econ_values.append(econ_value)
                                all_xis.append(xi)
                                all_rewards.append(reward)
                            
                        print(all_rewards)
                        print(all_xis)
                        ax[0].scatter(all_xis, all_rewards, label=h+f"eta={e} delta={d} icus={i} nmtests={nm} natests={na}")

                        ax[1].scatter(all_deaths, all_econ_values,label=h+f"eta={e} delta={d} icus={i} nmtests={nm} natests={na}")
                        print(all_econ_values)
                        print(all_deaths)
            

for x,y in zip(all_deaths, all_econ_values):

    label = "{:.2f}".format(all_xis[all_deaths.index(x)])

#     plt.annotate(label, # this is the text
#                         (x,y), # this is the point to label
#                         textcoords="offset points", # how to position the text
#                         xytext=(0,10), # distance from text to points (x,y)
#                         ha='center') # horizontal alignment can be left, right or center

ax[0].set(ylabal='Total Objective Value')
ax[0].set(xlabel='Xi')
box = ax[0].get_position()
# ax[0].set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax[0].legend(loc='center right', bbox_to_anchor=(1, 0.5))
plt.show()



ax[1].set(ylabel='Economic Value ($)')
ax[1].set(ylabel='Total Number of deaths')
box = ax[1].get_position()
# ax[1].set_position([box.x0, box.y0, box.width * 0.8, box.height])

# Put a legend to the right of the current axis
ax[1].legend(loc='center right', bbox_to_anchor=(1, 0.5))
plt.show()
            
# for eta in etas:
#     for delta in deltas:
#         for icu in icus:
#             for nmtest in nmtests:
#                 for natest in natests:
#                     for heur in heurs:
# Out:
# linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True
# ['xi-371990.3', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True
# ['xi-929975.75', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True
# ['xi-0.0', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True
# ['xi-3719903.0', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True
# ['xi-1859951.5', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=activity_gradient_targetGroups=False_targetAct=True_targetTests=True
# ['xi-5579854.5', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# [51686991233.83835, 50377494580.015465, 55178890639.79136, 45747929561.844795, 48108663034.806984, 42641168573.981575]
# [371990.3, 929975.75, 0.0, 3719903.0, 1859951.5, 5579854.5]
# [53245657869.577515, 52404407008.1486, 55178890639.79136, 51228446493.547714, 51449064866.76135, 48426005931.98749]
# [4190.073331856151, 2179.5325610728414, 8282.005446143012, 1473.2956562853708, 1795.9617936028797, 1036.7362371197867]
# activity_gradient
# ['xi-5579854', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-371990', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-929975', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-1859951', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-3719903', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-0', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# [42641168573.981575, 51685624230.01448, 50376091021.38435, 48033874976.33021, 45747929561.844795, 55178890639.79136]
# [5579854.0, 371990.0, 929975.0, 1859951.0, 3719903.0, 0.0]
# [48426005413.61936, 53240491407.93316, 52179534600.612465, 50524961443.68375, 51228446493.547714, 55178890639.79136]
# [1036.7362371197867, 4179.862840180325, 1939.2387744058856, 1339.3290830530152, 1473.2956562853708, 8282.005446143012]
# linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True
# ['xi-371990.3', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True
# ['xi-929975.75', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True
# ['xi-0.0', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True
# ['xi-3719903.0', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True
# ['xi-1859951.5', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=age_group_gradient_targetGroups=True_targetAct=False_targetTests=True
# ['xi-5579854.5', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# [51718985016.65679, 49846788041.28647, 54130900135.878, 45112517690.82114, 49354916163.54563, 42808717544.029144]
# [371990.3, 929975.75, 0.0, 3719903.0, 1859951.5, 5579854.5]
# [53934535093.68383, 52719100607.27927, 54130900135.878, 49282524781.899124, 52508738404.21966, 48962551154.41003]
# [5955.935079562661, 3088.5886712559973, 20559.816470023983, 1120.9988784863438, 1695.6475696672885, 1102.8663221202066]
# linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient
# ['xi-371990.3', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient
# ['xi-929975.75', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient
# ['xi-0.0', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient
# ['xi-3719903.0', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient
# ['xi-1859951.5', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# linearization_heuristic_optBouncing=False_initial_uhat=dynamic_gradient
# ['xi-5579854.5', 'icus-2000.0', 'testing-linearization', 'heuristic', 'natests-0', 'nmtests-0.0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.5', 'eta-0.1', 'lockdownFreq-14', 'testingFreq-7.yaml']
# [54841397259.967834, 53386390900.48801, 56083884726.097786, 48667859469.3798, 51343322290.891945, 46202041422.590096]
# [371990.3, 929975.75, 0.0, 3719903.0, 1859951.5, 5579854.5]
# [56088568488.310036, 55979510055.51402, 56083884726.097786, 54005411745.456215, 54954159972.908966, 53158755521.118866]
# [3352.6982513850585, 2788.372874266904, 4373.560171608154, 1434.8632951118393, 1941.3612032448282, 1246.7554662095167]
# time_gradient
# ['xi-5579854', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# time_gradient
# ['xi-371990', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# time_gradient
# ['xi-929975', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# time_gradient
# ['xi-1859951', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# time_gradient
# ['xi-3719903', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# time_gradient
# ['xi-0', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# [42228262356.569214, 50624665006.466034, 49529275084.69071, 46749938727.127335, 44214642600.131195, 53742343826.00204]
# [5579854.0, 371990.0, 929975.0, 1859951.0, 3719903.0, 0.0]
# [48187402553.2681, 52271789473.65815, 52334101440.51963, 51939612525.888016, 48187403087.25519, 53742343826.00204]
# [1067.974215221202, 4427.872972908192, 3016.023393993301, 2790.220709449164, 1067.974215221202, 26493.52170696921]
# activity_gradient
# ['xi-5579854', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-371990', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-929975', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-1859951', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-3719903', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# activity_gradient
# ['xi-0', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# [42641168573.981575, 51685624230.01448, 50376091021.38435, 48033874976.33021, 45747929561.844795, 55178890639.79136]
# [5579854.0, 371990.0, 929975.0, 1859951.0, 3719903.0, 0.0]
# [48426005413.61936, 53240491407.93316, 52179534600.612465, 50524961443.68375, 51228446493.547714, 55178890639.79136]
# [1036.7362371197867, 4179.862840180325, 1939.2387744058856, 1339.3290830530152, 1473.2956562853708, 8282.005446143012]
# age_group_gradient
# ['xi-5579854', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# age_group_gradient
# ['xi-371990', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# age_group_gradient
# ['xi-929975', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# age_group_gradient
# ['xi-1859951', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# age_group_gradient
# ['xi-0', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-3', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# age_group_gradient
# ['xi-3719903', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# age_group_gradient
# ['xi-0', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# [42228262356.569214, 50624665006.466034, 49529275084.69071, 49354916163.54563, 54130900135.878, 44214642600.131195, 54130900135.878]
# [5579854.0, 371990.0, 929975.0, 1859951.0, 0.0, 3719903.0, 0.0]
# [48187402553.2681, 52271789473.65815, 52334101440.51963, 52508737556.395874, 54130900135.878, 48187403087.25519, 54130900135.878]
# [1067.974215221202, 4427.872972908192, 3016.023393993301, 1695.6475696672885, 20559.816470023983, 1067.974215221202, 20559.816470023983]
# dynamic_gradient
# ['xi-5579854', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# dynamic_gradient
# ['xi-371990', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# dynamic_gradient
# ['xi-929975', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# dynamic_gradient
# ['xi-1859951', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# dynamic_gradient
# ['xi-3719903', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# dynamic_gradient
# ['xi-0', 'icus-2000', 'testing-homogeneous', 'natests-0', 'nmtests-0', 'T-90', 'startday-0', 'groups-all', 'dschool-0.500000', 'eta-0.100000', 'freq-90-14.yaml']
# [45976534014.16353, 54273297246.39445, 53287873579.17052, 50690762541.080154, 48576466055.755135, 56083884726.097786]
# [5579854.0, 371990.0, 929975.0, 1859951.0, 3719903.0, 0.0]
# [52717598996.87884, 55580024145.43019, 55912618283.316666, 54450247561.003006, 53880446566.13561, 56083884726.097786]
# [1208.1077717652308, 3512.8011479763973, 2822.382003974457, 2021.2817541552736, 1425.8383915872216, 4373.560171608154]
